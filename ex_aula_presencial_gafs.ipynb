# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# C:\Users\arnch\AppData\Local\Temp\ipykernel_10288\639272751.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights_long.pivot("month", "year", "passengers")
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# #LaTex
# #coloca equação no meio de $$ para deixa-la igual equação matematica
# $ax^2 + bx + c = 0$

# %%
2
# Out:
# 2
